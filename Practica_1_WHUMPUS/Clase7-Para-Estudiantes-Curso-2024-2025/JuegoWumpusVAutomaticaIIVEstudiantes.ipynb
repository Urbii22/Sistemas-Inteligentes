# %% [markdown]
# <img style="float:left" width="70%" src="pics/escudo_COLOR_1L_DCHA.png">
# <img style="float:right" width="15%" src="pics/PythonLogo.svg">
# <br style="clear:both;">
#
#
# # *Wumpus*
# ### *Sistemas Inteligentes* (Curso 2024-2025)
#
#
#
# <h2 style="display: inline-block; padding: 4mm; padding-left: 2em; background-color: navy; line-height: 1.3em; color: white; border-radius: 10px;">Hacia la versión "automática" del juego (II) </h2>
#
# ## Docentes
#
#  - Pedro Latorre Carmona

# %% [markdown]
# ## Definición de la clase
#
# Partimos de la definición de la clase **Tablerowumpus** que se ha estado viendo en las semanas anteriores, y tenemos que introducir el método de **MINIMAX**.

# %%
from copy import deepcopy
from typing import Tuple, List

# %%
class Tablerowumpus:
    
    
    def __init__(self, matrix):
        
      
    
    
    def __eq__(self, other) -> bool:
        
       
    
    
    def setMatrix(self, matrix):
        self.matrix = deepcopy(matrix)
    
    
    
    
    def getMatrix(self) -> List[List]:
        return deepcopy(self.matrix)
       
    
    
    def canMoveUp(self,row: int, col: int) -> bool:
        
  
    
    

    def canMoveDown(self,row: int, col: int) -> bool:
 


    

    def canMoveLeft(self,row: int, col: int) -> bool:
        
 
    


    def canMoveRight(self,row: int, col: int) -> bool:
     
 
    

    
    def getAvailableMovesForMax(self,row: int, col: int) -> List[int]:
   
        
    
    
    
    def getAvailableMovesForMin(self) -> List[Tuple[int]]:
 


    
    
    def moveCanBeMade(self,player: int) -> bool:
        
                
        
        
    
    def isGameOver(self) -> bool:

# %% [markdown]
# ## Función asociada al método *Minimax* (con poda $\alpha-\beta$)

# %%
def miniMax(state:Tablerowumpus, currentLevel:int, maxLevel:int, player:int, alpha:int, beta:int, stop:bool) -> Tuple[Tablerowumpus, int, bool]:

    matriz=state.getMatrix()
    
    # Defino las matrices de sucesores
    
    successorMatrices = []
    
    if (not state.moveCanBeMade(player) or currentLevel == maxLevel):
        return (state.matrix,state.utility(),stop)  
    
    # ====================================================================================================
    #
    # A esta altura, si queréis podéis definir la fórmula de la función de coste, o llamarla.
    #
    # ====================================================================================================
          
    
    # =========================================================================================
    # Voy a generar el conjunto de los potenciales HIJOS/SUCESORES (en "successorMatrices"), y los voy a ir añadiendo
    # a "successormatrices".
    #
    # COMPLETAD, REHACED...COMO VEÁIS...
    #
    # La variable "successorBoard" bajo DEFINE UNO de los potenciales HIJOS.
    #
    # =========================================================================================           
    
    
    successorMatrices.append(successorBoard)
          
     
    if len(successorMatrices) == 0:
        stopDigging = True
        coste=state.utility()
        return (statematrix,coste,stopDigging)
    
    bestMatrix = None
    
    # En la siguiente línea, tenéis que definir adecuadamente el "IF".
    
    #if player == JugadorA: Aquí tenéis que poner el jugador que corresponda                   
        maxValue = -math.inf #alpha
        
        for i in range(0, len(successorMatrices)):            
            
                mat = Tablerowumpus(successorMatrices[i])            
                #matrizS, utility, stop = miniMax(mat, currentLevel + 1, maxLevel, JugadorB, alpha,beta,stop)
                
                best = utility 
            
                if best > maxValue:
                    maxValue = best
                    bestMatrix = ...
            
            
            
                # COSAS...
            
            
            
                alpha = max(alpha, best)                
                if best >= beta:
                                           
                    return (matrizS,best,stop)
            
            
    else:                           
        
        minValue = math.inf #beta
        for i in range(0, len(successorMatrices)):
            
            
                mat = Tablerowumpus(successorMatrices[i])
                #matrizS, utility, stop = miniMax(mat, currentLevel + 1, maxLevel, JugadorA, alpha,beta,stop)
            
            
                if utility < minValue:
                
                    minValue = utility
                    bestMatrix = ...
                
                
                
                # COSAS...
            
            
            
                beta = min(beta, utility)
                if utility <= alpha:                    
                
                   return (matrizS,utility,stop)
            
                       
            
     # Toda esta parte, a rellenar.
    
            
            
            
            
    return (bestMatrix,utility,stop)

# %% [markdown]
# ---
# ## Poner en funcionamiento Minimax
#
# Una vez realizada/terminada la función que implementa el algoritmo de **MINIMAX**, podemos *ponerla en funcionamiento*.

# %%
def performActionMinMax(state:Tablerowumpus, player:int):
    
    matrizB=state.getMatrix()
        
    tmpMatriz = [row[:] for row in matrizB] 
           
        
    # ==================================================
    # Valor de profundidad que queráis. Yo recomiendo 2
    
    # depth = ........
    
    
    matrizoptima = tmpMatriz
    stop = False 
    currentLevel = 0    
    itera = 0  
    
    tmpMatrizB = Tablerowumpus(tmpMatriz)
    (matrizoptima, valoroptimo, stop) = miniMax(tmpMatrizB, currentLevel, depth, player , -math.inf, math.inf,stop);        
            
        
   # ====================================================================================================================
   #
   # COSAS QUE FALTAN/FALTEN POR PONER
   #    
   # ====================================================================================================================     
        
        
    return XXXXXXXXXXXXXXXXXXXXXXXX

# %% [markdown]
# ## Realización del movimiento por parte del *agente*
#
# Definimos una función que, cuando se realice, haga el movimiento del *agente*.

# %%
def AIAction(state:Tablerowumpus, player:int):
    
    global AIReadyToMove

    matriz=state.getMatrix()
    
    # ======================================================================================================
    #
    # Aquí, habría que hacer la llamada a "performActionMinMax", de la forma como sea más adecuado/a
    
    
    #  YYYYY=performActionMinMax(Tablerowumpus(matriz),player)
    #
    # ======================================================================================================
        
        
    AIReadyToMove = False
   

   # =======================================================================================================
   #
   # Hay que cambiar, AL MENOS, la línea siguiente del RETURN.
   #    
   # ======================================================================================================= 

    
    return YYYYY

# %% [markdown]
# ## ¿Cómo podríamos probar que funciona?
#
# Una cosa que os sugiero se podría hacer, es:

# %%
# LO_QUE_SEA = performActionMinMax(Tablerowumpus(matrix=instEjemplo.getMatrix()),JugadorAdecuado)

# %%
# LO_QUE_SEA_B = AIMove(Tablerowumpus(matrix=instEjemplo.getMatrix()),JugadorAdecuado)
