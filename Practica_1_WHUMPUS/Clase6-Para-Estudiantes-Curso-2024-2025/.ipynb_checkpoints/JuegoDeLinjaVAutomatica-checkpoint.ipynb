# %% [markdown]
# <img style="float:left" width="70%" src="pics/escudo_COLOR_1L_DCHA.png">
# <img style="float:right" width="15%" src="pics/PythonLogo.svg">
# <br style="clear:both;">
#
#
# # *Linja*
# ### *Sistemas Inteligentes* (Curso 2023-2024)
#
#
#
# <h2 style="display: inline-block; padding: 4mm; padding-left: 2em; background-color: navy; line-height: 1.3em; color: white; border-radius: 10px;">Hacia la versión "automática" del juego (I) </h2>
#
# ## Docentes
#
#  - Pedro Latorre Carmona

# %% [markdown]
# ## Definición de la clase
#
# Partimos de la definición de la clase **Tablerolinja** que se ha estado viendo en las semanas anteriores, y tenemos que introducir el método de **MINIMAX**.

# %%
from copy import deepcopy
from typing import Tuple, List

# %%
class Tablerolinja:
    
    def __init__(self, matrix):
        self.setMatrix(matrix)
    
    
    def __eq__(self, other) -> bool:
        
        for i in range(8):
            for j in range(6):
                if self.matrix[i][j] != other.matrix[i][j]:
                    return False
        return True
    
    
    def setMatrix(self, matrix):
        self.matrix = deepcopy(matrix)
    
    
    def getMatrix(self) -> List[List]:
        return deepcopy(self.matrix)
    
    
    def placeTile(self, row: int, col: int, tile: int):
        self.matrix[row-1][col-1] = tile
    
        
        
        
    # ====================================================
    #
    # TODO EL RESTO DE CÓDIGO QUE SEA NECESARIO
    #
    # ====================================================

# %% [markdown]
# ## Función asociada al método *Minimax* (con poda $\alpha-\beta$)

# %%
def miniMax(state:Tablerolinja, currentLevel:int, maxLevel:int, player:int, alpha:int, beta:int, stop:bool) -> Tuple[Tablerolinja, int]:

    matriz=state.getMatrix()
    
    # Defino las matrices de sucesores
    
    successorMatrices = []
    
    if (not state.moveCanBeMade(player) or currentLevel == maxLevel):
        return (state.matrix,state.utility(),stop)  
    
    # ====================================================================================================
    #
    # A esta altura, si queréis podéis definir la fórmula de la función de coste, o llamarla.
    #
    # ====================================================================================================
          
   

    # Actualizo el conjunto de las matrices de sucesores
    
    for row in range(0, 8):
        for col in range(0, 6):
            
            
            
            # COMPLETAD, REHACED...COMO VEÁIS...
            
     
    if len(successorMatrices) == 0:
        stopDigging = True
        coste=state.utility()
        return (statematrix,coste,stopDigging)
    
    bestMatrix = None
    
            
    if player == 2:                    
        maxValue = -math.inf #alpha
        
        for i in range(0, len(successorMatrices)):
            
            
                # ==============================================================================================
                #
                # matrizS, utility = miniMax(....)   # DEBE CONTENER LA LLAMADA AL OTRO JUGADOR (i. e., "1")
            
                # A rellenar
                
                
                # Aquí es donde se tiene que buscar el estado que proporciona el MÁXIMO de la función de coste.
                # 
                # ================================================================================================
            
                if best > maxValue:
                    maxValue = best
                    bestMatrix = ...
            
            
            
                # COSAS...
            
            
            
                alpha = max(alpha, best)                
                if best >= beta:
                                           
                    return (matrizS,best,stop)
            
            
    else:                           
        
        minValue = math.inf #beta
        for i in range(0, len(successorMatrices)):
            
            
           # matrizS, utility = miniMax(....)   # DEBE CONTENER LA LLAMADA AL OTRO JUGADOR (i. e., "2")
            
            
            
                 # A rellenar
                
                
                
                # Aquí es donde se tiene que buscar estado que proporciona el MÍNIMO de la función de coste.
                # 
                # =============================================================================================
            
            
                if utility < minValue:
                
                    minValue = utility
                    bestMatrix = ...
                
                
                
                # COSAS...
            
            
            
                beta = min(beta, utility)
                if utility <= alpha:                    
                
                   return (matrizS,utility,stop)
            
                       
            
     # Toda esta parte, a rellenar.
    
            
            
            
            
    return (bestMatrix,utility,stop)

# %% [markdown]
# ---
# ## Poner en funcionamiento Minimax
#
# Una vez realizada/terminada la función que implementa el algoritmo de **MINIMAX**, podemos *ponerla en funcionamiento*.

# %%
def performMoveMinMax(state:Tablerolinja, player:int):
    
    matrizB=state.getMatrix()
        
        
        
        
   # A COMPLETAR     
        
        
        
        
        
    return XXXXXXXXXXXXXXXXXXXXXXXX
